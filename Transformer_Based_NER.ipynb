# %%
import spacy
import random
from spacy.tokens import DocBin
from tqdm.notebook import tqdm  # for progress bars

# %%
import os

# Function to load data in IOB format (e.g., CoNLL format)
def load_data(file_path):
    sentences = []
    sentence = []

    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            line = line.strip()
            if line == "":
                if sentence:
                    sentences.append(sentence)
                    sentence = []
            elif not line.startswith("-DOCSTART-"):
                parts = line.split()
                token = parts[0]
                label = parts[-1]  # Assuming the label is in the last column
                sentence.append((token, label))
        if sentence:
            sentences.append(sentence)
    return sentences

# Load training and validation data
train_data = load_data("/content/eng.train")
dev_data = load_data("/content/eng.testa")
test_data = load_data("/content/eng.testb")

# Function to convert data to spaCy's DocBin format
def convert_to_spacy(data, output_path):
    nlp = spacy.blank("en")  # Initialize blank English model
    db = DocBin()  # Create a DocBin for storing processed data

    for sentence in tqdm(data):
        tokens = [token for token, label in sentence]
        labels = [label for token, label in sentence]

        doc = nlp.make_doc(" ".join(tokens))  # Create Doc object from text
        ents = []

        for i, (token, label) in enumerate(sentence):
            if label != "O":
                label_type = label.split("-")[-1]  # Get entity type
                if label.startswith("B-"):
                    # Find the start and end based on token index instead of character position
                    start = i
                    end = i + 1
                    ents.append(spacy.tokens.Span(doc, start=start, end=end, label=label_type))

        doc.ents = ents
        db.add(doc)

    db.to_disk(output_path)  # Save to disk

# Convert data and save it
convert_to_spacy(train_data, "train.spacy")
convert_to_spacy(dev_data, "dev.spacy")
# Out:
#   0%|          | 0/14041 [00:00<?, ?it/s]
#   0%|          | 0/3250 [00:00<?, ?it/s]

# %%
# Initialize transformer-based config for NER
# !python -m spacy init config config.cfg --lang en --pipeline ner --optimize efficiency --gpu
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: GPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# Train the model with transformer-based config
# !python -m spacy train /content/config.cfg --output /content/output --paths.train /content/train.spacy --paths.dev /content/dev.spacy --gpu-id 0
# Out:
# ✔ Created output directory: /content/output
# ℹ Saving to output directory: /content/output
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     44.28    0.00    0.00    0.00    0.00
#   0     200         65.13   3271.47   46.69   52.91   41.79    0.47
#   0     400        152.94   2449.57   62.64   63.93   61.41    0.63
#   0     600        200.24   2463.64   69.82   70.61   69.05    0.70
#   0     800        252.84   2659.69   71.33   72.76   69.96    0.71
#   0    1000        302.93   3057.73   72.52   76.53   68.92    0.73
#   1    1200        373.69   3299.78   76.10   77.21   75.03    0.76
#   1    1400        476.12   3113.21   76.30   78.91   73.86    0.76
#   1    1600        552.79   3820.62   77.00   79.74   74.44    0.77
#   2    1800        671.52   4021.57   77.76   79.57   76.04    0.78
#   2    2000        855.70   4441.41   77.60   79.66   75.65    0.78
#   3    2200        988.78   4120.51   77.98   80.49   75.61    0.78
#   4    2400       1266.03   4454.73   78.46   80.05   76.93    0.78
#   5    2600       1349.15   3876.00   77.53   80.00   75.21    0.78
#   6    2800       1312.16   3222.30   77.92   79.27   76.62    0.78
#   7    3000       1372.00   2964.07   77.59   79.78   75.51    0.78
#   8    3200       1356.65   2570.33   77.08   78.88   75.36    0.77
#   9    3400       1351.55   2345.20   77.84   80.31   75.51    0.78
#   9    3600       1253.90   2054.52   77.90   80.10   75.82    0.78
#  10    3800       1160.07   1850.11   77.08   79.11   75.14    0.77
#  11    4000       1207.79   1860.98   76.92   77.95   75.92    0.77
# ✔ Saved pipeline to output directory
# /content/output/model-last

# %%
# Load the best trained model
nlp_trained = spacy.load("/content/output/model-best")

# Prepare test data by converting each test sentence to plain text
test_sentences = [" ".join([token for token, label in sentence]) for sentence in test_data]

# Process test sentences through the model to get predictions
test_docs = list(nlp_trained.pipe(test_sentences))
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
from spacy import displacy

# Display sample predictions
for i, doc in enumerate(test_docs[:5]):  # Show first 5 examples
    print(f"Document {i+1}:")
    print("Text:", doc.text)
    if doc.ents:
        displacy.render(doc, style="ent", jupyter=True)
    else:
        print("No entities found.")
    print("\n" + "-"*50 + "\n")
# Out:
# Document 1:
# Text: SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRISE DEFEAT .
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">SOCCER -
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JAPAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  GET LUCKY WIN ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHINA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  IN
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SURPRISE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  DEFEAT .</div></span>
# --------------------------------------------------
#
# Document 2:
# Text: Nadim Ladki
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nadim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Ladki</div></span>
# --------------------------------------------------
#
# Document 3:
# Text: AL-AIN , United Arab Emirates 1996-12-06
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AIN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , United Arab Emirates 1996-12-06</div></span>
# --------------------------------------------------
#
# Document 4:
# Text: Japan began the defence of their Asian Cup title with a lucky 2-1 win against Syria in a Group C championship match on Friday .
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  began the defence of their
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Cup title with a lucky 2-1
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     win
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  against Syria
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  a Group C championship match on Friday .</div></span>
# --------------------------------------------------
#
# Document 5:
# Text: But China saw their luck desert them in the second match of the group , crashing to a surprise 2-0 defeat to newcomers Uzbekistan .
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">But
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  saw their luck desert them in the second match of the group , crashing to a surprise 2-0 defeat to newcomers
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Uzbekistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  .</div></span>
# --------------------------------------------------

# %%
from sklearn.metrics import classification_report

# Modified to include both tokens and labels
true_entities = [[(token, label) for token, label in sentence] for sentence in test_data]
predicted_entities = [[ent.label_ if ent else "O" for ent in doc.ents] for doc in test_docs]

# Modified logic to handle length differences and align predictions with true labels
y_true = []
y_pred = []

for true_sent, pred_doc in zip(true_entities, test_docs):
    pred_labels = ["O"] * len(true_sent)  # Initialize with 'O' for all tokens

    # Align based on token text matching
    pred_idx = 0
    for true_idx, (true_token, true_label) in enumerate(true_sent): # Unpack now works
        if pred_idx < len(pred_doc) and true_token == pred_doc[pred_idx].text:
            if pred_doc[pred_idx].ent_iob_ != "O":
                pred_labels[true_idx] = pred_doc[pred_idx].ent_type_
            pred_idx += 1

    y_true.extend([label for _, label in true_sent])  # Extract true labels
    y_pred.extend(pred_labels)

# Print classification report
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#        B-LOC       0.00      0.00      0.00      1668
#       B-MISC       0.00      0.00      0.00       702
#        B-ORG       0.00      0.00      0.00      1661
#        B-PER       0.00      0.00      0.00      1617
#        I-LOC       0.00      0.00      0.00       257
#       I-MISC       0.00      0.00      0.00       216
#        I-ORG       0.00      0.00      0.00       835
#        I-PER       0.00      0.00      0.00      1156
#          LOC       0.00      0.00      0.00         0
#         MISC       0.00      0.00      0.00         0
#            O       0.91      0.99      0.95     38323
#          ORG       0.00      0.00      0.00         0
#          PER       0.00      0.00      0.00         0
#
#     accuracy                           0.82     46435
#    macro avg       0.07      0.08      0.07     46435
# weighted avg       0.75      0.82      0.78     46435

# %%
from google.colab import files
# !zip -r my_project.zip /content
files.download('my_project.zip')
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2024.11.05/ (stored 0%)
#   adding: content/.config/logs/2024.11.05/14.22.44.376709.log (deflated 56%)
#   adding: content/.config/logs/2024.11.05/14.22.21.093074.log (deflated 58%)
#   adding: content/.config/logs/2024.11.05/14.22.33.100027.log (deflated 58%)
#   adding: content/.config/logs/2024.11.05/14.22.32.000952.log (deflated 85%)
#   adding: content/.config/logs/2024.11.05/14.22.43.731153.log (deflated 57%)
#   adding: content/.config/logs/2024.11.05/14.22.00.037214.log (deflated 93%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 23%)
#   adding: content/.ipynb_checkpoints/ (stored 0%)
#   adding: content/dev.spacy (deflated 6%)
#   adding: content/config.cfg (deflated 61%)
#   adding: content/drive/ (stored 0%)
#   adding: content/drive/.file-revisions-by-id/ (stored 0%)
#   adding: content/drive/MyDrive/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/CV/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Cover Letter.pdf (deflated 7%)
#   adding: content/drive/MyDrive/Very Important Files/CV/My_CV_EEE_.pdf (deflated 19%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Ahmed-Mohamed-Kamal-Ali-CV.pdf (deflated 34%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Ahmed CV (EGY).pdf (deflated 35%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Cover Letter.docx (deflated 18%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Old/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Old/Ahmed Mohamed Kamal CV.pdf (deflated 11%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Old/My CV.docx (deflated 11%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Old/Ahmed Mohamed Kamal_CV.pdf (deflated 20%)
#   adding: content/drive/MyDrive/Very Important Files/CV/Old/Ahmed_Kamal_CV.pdf (deflated 19%)
#   adding: content/drive/MyDrive/Very Important Files/AL HOSN/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/AL HOSN/ALHOSN_Vaccination_Report.pdf (deflated 13%)
#   adding: content/drive/MyDrive/Very Important Files/AL HOSN/ALHOSN_Test_Result.pdf (deflated 6%)
#   adding: content/drive/MyDrive/Very Important Files/AL HOSN/ALHOSN_Test_Result (1).pdf (deflated 6%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Training Certificate.pdf (deflated 9%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Bachelor  Transcript (En).pdf (deflated 0%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Graduation Completion letter (En).pdf (deflated 0%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/AlumniCard.pdf (deflated 7%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Graduation Completion letter (Ar).pdf (deflated 45%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Cert. of good conduct.pdf (deflated 0%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/انتظام في الدراسة.pdf (deflated 47%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Bachelor Certificate (Ar).pdf (deflated 5%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Bachelor  Transcript (Ar).pdf (deflated 6%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Bachelor Certificate (En).pdf (deflated 5%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Bachelor Certificate (معادلة).pdf (deflated 3%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Attested/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Attested/Official Transcript.pdf (deflated 6%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Attested/Bachelor Certificate.pdf (deflated 5%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Attested/انتظام في الدراسة.pdf (deflated 24%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Safety Course Certificates/ (stored 0%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Safety Course Certificates/U17101761@sharjah.ac.ae - Electrical Safety _ N(1).pdf (deflated 4%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/Safety Course Certificates/U17101761@sharjah.ac.ae - Central Labs Safety O.pdf (deflated 2%)
#   adding: content/drive/MyDrive/Very Important Files/Certificates/Bachelor Certificates/
 (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Certificates/School Certificates/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Certificates/School Certificates/Gr 1-12/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Admission Docs/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Admission Docs/AU TA enrollment/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Admission Docs/UOS admission/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Admission Docs/AU admission/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Admission Docs/Oman Transfer Documents/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Health insurance/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Health insurance/Old/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/IELTS/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Ibrahim Certificates/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Mashreq Bank/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Mashreq Bank/Monthly statements/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Mashreq Bank/SWIFT statements/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Others/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/School Admission/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Photograph/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/المجلس الأعلى للجامعات/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/المجلس الأعلى للجامعات/معادلة البكالوريوس/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/المجلس الأعلى للجامعات/معادلة البكالوريوس/Scans/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Personal Docs/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Personal Docs/Prev. UAE Visa/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/مستندات التجنيد/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/مستندات التجنيد/بعثات 21-22/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/مستندات التجنيد/بعثات 22-23/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/مستندات التجنيد/فتح ملف بعثات 2021/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/مستندات التجنيد/تصريح سفر/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/مستندات التجنيد/بعثات 23-24/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Very Important Files/Family Docs/ (stored 0%)
#   adding: content/drive/.Encrypted/MyDrive/Colab Notebooks/ (stored 0%)
#   adding: content/drive/.Encrypted/.shortcut-targets-by-id/ (stored 0%)
#   adding: content/output/ (stored 0%)
#   adding: content/output/model-last/ (stored 0%)
#   adding: content/output/model-last/config.cfg (deflated 61%)
#   adding: content/output/model-last/tokenizer (deflated 81%)
#   adding: content/output/model-last/vocab/ (stored 0%)
#   adding: content/output/model-last/vocab/strings.json (deflated 73%)
#   adding: content/output/model-last/vocab/key2row (stored 0%)
#   adding: content/output/model-last/vocab/vectors (deflated 45%)
#   adding: content/output/model-last/vocab/lookups.bin (stored 0%)
#   adding: content/output/model-last/vocab/vectors.cfg (stored 0%)
#   adding: content/output/model-last/ner/ (stored 0%)
#   adding: content/output/model-last/ner/cfg (deflated 33%)
#   adding: content/output/model-last/ner/moves (deflated 59%)
#   adding: content/output/model-last/ner/model (deflated 9%)
#   adding: content/output/model-last/tok2vec/ (stored 0%)
#   adding: content/output/model-last/tok2vec/cfg (stored 0%)
#   adding: content/output/model-last/tok2vec/model (deflated 8%)
#   adding: content/output/model-last/meta.json (deflated 58%)
#   adding: content/output/model-best/ (stored 0%)
#   adding: content/output/model-best/config.cfg (deflated 61%)
#   adding: content/output/model-best/tokenizer (deflated 81%)
#   adding: content/output/model-best/vocab/ (stored 0%)
#   adding: content/output/model-best/vocab/strings.json (deflated 73%)
#   adding: content/output/model-best/vocab/key2row (stored 0%)
#   adding: content/output/model-best/vocab/vectors (deflated 45%)
#   adding: content/output/model-best/vocab/lookups.bin (stored 0%)
#   adding: content/output/model-best/vocab/vectors.cfg (stored 0%)
#   adding: content/output/model-best/ner/ (stored 0%)
#   adding: content/output/model-best/ner/cfg (deflated 33%)
#   adding: content/output/model-best/ner/moves (deflated 59%)
#   adding: content/output/model-best/ner/model (deflated 9%)
#   adding: content/output/model-best/tok2vec/ (stored 0%)
#   adding: content/output/model-best/tok2vec/cfg (stored 0%)
#   adding: content/output/model-best/tok2vec/model (deflated 8%)
#   adding: content/output/model-best/meta.json (deflated 58%)
#   adding: content/train.spacy (deflated 6%)
#   adding: content/eng.testb (deflated 81%)
#   adding: content/eng.train (deflated 80%)
#   adding: content/eng.testa (deflated 80%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 39%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
